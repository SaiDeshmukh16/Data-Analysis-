# %% [markdown]
# # Pandas challenges
# You may have noticed that all the way along we've been giving you links to documentation to explore the attributes, functions, and methods further. This is an important part of coding: nobody has everything memorised, but we are all experts at Googling the information we need quickly.
#
# In this notebook we've included a couple of challenges that require methods we haven't taught you - this is a purposeful move to start your path to Google glory. Search around, read pandas docs, stack overflow, medium, and anywhere else you find information.
#
# If you're totally stuck feel free to ask your "colleagues" (fellow students), your instructor, or one of our junior instructors. Most of the time though, we'll have taught you the answer in one of the previous notebooks, please check back in them too. They will be a great source of information throughout this bootcamp.

# %%
import pandas as pd

# %% [markdown]
# ###### **Exercise 1:**
# read the `vehicles.csv` dataframe and store it in a variable called `cars`:

# %%
# vehicles.csv 'https://drive.google.com/file/d/18zYGrzRhn_mz1HJLXxSO_MwR0_nWBS3K/view?usp=sharing'

# your code here
#import pandas as pd
#path = 'https://drive.google.com/uc?export=download&id=%27+url.split(%27/%27)[-2]
#cars = pd.read_csv(path)
#cars = pd.read_csv('https://drive.google.com/file/d/18zYGrzRhn_mz1HJLXxSO_MwR0_nWBS3K/view?usp=sharing')
#print(cars)

url = 'https://drive.google.com/file/d/18zYGrzRhn_mz1HJLXxSO_MwR0_nWBS3K/view?usp=sharing' # vehicles.csv
path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
cars = pd.read_csv(path)
print(cars)
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# ###### **Exercise 2:**
# how many rows and columns are there?

# %%
# your code here
#rows_column = cars.shape
print(cars.shape)
# Out:
# (35952, 15)

# %% [markdown]
# ###### **Exercise 3:**
# what are the data types of the columns? Are there missing values?

# %%
# your code here
#data_type = cars.dtype()
#print(data_type)

null_value_check = cars.info()
#print(cars.head())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
# ...

# %% [markdown]
# ###### **Exercise 4:**
# what are the ranges / distributions of the numerical columns?

# %%
# your code here
#range = cars.hist(bins=4)
cars.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# ...

# %% [markdown]
# ###### **Exercise 5:**
# what are the value counts of the `Fuel Type` column?

# %%
# your code here
#import pandas as pd
#cars = pd.read_csv('https://drive.google.com/file/d/18zYGrzRhn_mz1HJLXxSO_MwR0_nWBS3K/view?usp=sharing')
#print(cars["Year"].value_counts())
#print(cars['Fuel Type'].value_counts())


cars["Fuel Type"].value_counts()
# Out:
# Regular                        23587
# Premium                         9921
# Gasoline or E85                 1195
# Diesel                           911
# Premium or E85                   121
# Midgrade                          74
# CNG                               60
# Premium and Electricity           20
# Gasoline or natural gas           20
# Premium Gas or Electricity        17
# Regular Gas and Electricity       16
# Gasoline or propane                8
# Regular Gas or Electricity         2
# Name: Fuel Type, dtype: int64

# %% [markdown]
# ###### **Exercise 6:**
# drop the column "Combined MPG"

# %%
# your code here
cars.drop(columns=['Combined MPG'])
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# ###### **Exercise 7:**
# change the column names so that there are no names with spaces or weird special characters:

# %%
# your code here
cars = cars.rename(columns={'Engine Displacement': 'EngineDisplacement', 'Fuel Type':'FuelType','Vehicle Class': 'VehicleClass', 'Fuel Barrels/Year':'FuelBarrelsPerYear', 'City MPG':'CityMPG' ,'Highway MPG':'HighwayMPG' , 'Combined MPG':'CombinedMPG', 'CO2 Emission Grams/Mile':'CO2EmissionGramsPerMile', 'Fuel Cost/Year':'FuelCostPerYear'})
cars.head()
#cars.columns = cars.columns.str.replace(' ', '_')
#cars.columns = cars.columns.str.replace('/','_')
# Out:
#                Make                Model  Year  EngineDisplacement  Cylinders  \
# 0        AM General    DJ Po Vehicle 2WD  1984                 2.5        4.0
# 1        AM General     FJ8c Post Office  1984                 4.2        6.0
# 2        AM General  Post Office DJ5 2WD  1985                 2.5        4.0
# 3        AM General  Post Office DJ8 2WD  1985                 4.2        6.0
# 4  ASC Incorporated                  GNX  1987                 3.8        6.0
#
#       Transmission        Drivetrain                 VehicleClass FuelType  \
# 0  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD  Regular
# 1  Automatic 3-spd     2-Wheel Drive  Special Purpose Vehicle 2WD  Regular
# 2  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD  Regular
# 3  Automatic 3-spd  Rear-Wheel Drive  Special Purpose Vehicle 2WD  Regular
# 4  Automatic 4-spd  Rear-Wheel Drive                 Midsize Cars  Premium
#
# ...

# %% [markdown]
# ###### **Exercise 8:**
# what brand has the most cars?

# %%
# your code here
occur = cars.groupby(['Make']).size()
#print(max(occur))
#cars["Make"].value_counts()

# %% [markdown]
# ###### **Exercise 9:**
# what brand has the worse CO2 Emissions on average?

# %%
# your code here
#groupbybrands = cars.groupby(['Make'])
#meanbybrands = groupbybrands["CO2EmissionGramsPerMile"].mean()
#maxco2emission = 
## your code here
#cars.groupby("CO2_Emission_Gram_per_Mile").max().tail(3)

cars.groupby("Make").CO2EmissionGramsPerMile.mean().sort_values(ascending=False)
# Out:
# Make
# Vector                                1049.159722
# Superior Coaches Div E.p. Dutton       888.700000
# S and S Coach Company  E.p. Dutton     888.700000
# Bugatti                                873.062500
# Laforza Automobile Inc                 807.909091
#                                          ...
# MINI                                   313.716862
# Daihatsu                               310.188060
# Fiat                                   304.666560
# smart                                  247.030556
# Fisker                                 169.000000
# Name: CO2EmissionGramsPerMile, Length: 127, dtype: float64

# %% [markdown]
# ###### **Exercise 10:**
# did cars consume more gas in the eighties?

# %%
# your code here
cars.groupby("Year").FuelBarrelsPerYear.mean()

#cars[cars.Year.isin(['1984','1981','1982','1983','1980','1985','1986','1987','1988','1989'])]
 
Eightys = cars[(cars.Year == 1984) | (cars.Year == 1985) | (cars.Year == 1986) | (cars.Year == 1987)| (cars.Year == 1988)]
Ninties = cars[(cars.Year == 1990) | (cars.Year == 1991)|(cars.Year == 1992) | (cars.Year == 1993)|(cars.Year == 1994) | (cars.Year == 1995)|(cars.Year == 1996) | (cars.Year == 1997)|(cars.Year == 1999)]
twothousands = cars[(cars.Year == 2000) | (cars.Year == 2001) | (cars.Year == 2002) | (cars.Year == 2003)| (cars.Year == 2004) |(cars.Year == 2005) | (cars.Year == 2006) | (cars.Year == 2007) | (cars.Year == 2008)| (cars.Year == 2009)]
twotens = cars[(cars.Year == 2010) | (cars.Year == 2011) | (cars.Year == 2012) | (cars.Year == 2013)| (cars.Year == 2014) |(cars.Year == 2015) | (cars.Year == 2016) | (cars.Year == 2017)]

print(Eightys.FuelBarrelsPerYear.mean())
print(Ninties.FuelBarrelsPerYear.mean())
print(twothousands.FuelBarrelsPerYear.mean())
print(twotens.FuelBarrelsPerYear.mean())

#year_points = [1980, 1990, 2000, 2010,2020]
#cars['decade'] = pd.cut(x = cars['Year'], bins=year_points, labels=[u'80s', u'90s', u'00s', u'10s'])
#cars_decade = cars.groupby('decade')
#cars_decade.head()
#print(cars_decade["Fuel Cost/Year"].mean())
  

#make a new column decade
#cars['Decade'] = (cars['Year'] // 10) * 10
#cars.groupby('Decade').Fuel_Barrels_per_Year.mean()
# Decade 1980 - 1989 has with 18.55 the highest average
#gasEighties = cars.query('Year > 1980 & Year < 1989').mean()
#gasEighties.Fuel_Barrels_per_Year
# Out:
# 18.564032974319936
# 18.33843802923167
# 17.962476690298235
# 15.778968389498

# %% [markdown]
# ###### **Exercise 11:**
# group cars by fuel type and aggregate them by the following criteria:
#
# - The maximum number cylinders
# - The oldest year
# - The average Miles Per Gallon in the city

# %%
# your code here
cars_group = cars.groupby(['FuelType'])
cars_group["Cylinders"].max()
cars_group['Year'].min()
cars_group['CityMPG'].mean()

##Using groupby('').aggregate
#Fuel_Type_Aggregates = cars.groupby("Fuel_Type").aggregate({'Cylinders':'max', 'Year':'min', 'City_MPG':'mean'})
#print(Fuel_Type_Aggregates)
# Out:
# FuelType
# CNG                            15.966667
# Diesel                         21.173436
# Gasoline or E85                15.347280
# Gasoline or natural gas        13.700000
# Gasoline or propane            12.000000
# Midgrade                       14.851351
# Premium                        16.793166
# Premium Gas or Electricity     30.705882
# Premium and Electricity        24.900000
# Premium or E85                 17.305785
# Regular                        17.970195
# Regular Gas and Electricity    43.125000
# Regular Gas or Electricity     43.000000
# Name: CityMPG, dtype: float64

# %% [markdown]
# ###### **Exercise 12:**
# read the `car_brands.csv` data:

# %%
# car_brands.csv 'https://drive.google.com/file/d/1jLSArDeSsySULKiRtMNV3V3RKuWAUKbD/view?usp=sharing'
#url = 'https://drive.google.com/file/d/18zYGrzRhn_mz1HJLXxSO_MwR0_nWBS3K/view?usp=sharing' # vehicles.csv
#path = 'https://drive.google.com/uc?export=download&id='+url.split('/')[-2]
#cars = pd.read_csv(path)
#print(cars)

# your code here
url1 = 'https://drive.google.com/file/d/1jLSArDeSsySULKiRtMNV3V3RKuWAUKbD/view?usp=sharing'
path1 = 'https://drive.google.com/file/d/1jLSArDeSsySULKiRtMNV3V3RKuWAUKbD/view?usp=sharing'+url1.split('/')[-2]
CarBrands = pd.read_csv(path1)
print(CarBrands)
# Out:
#     <!DOCTYPE html><html><head><meta name="google" content="notranslate"><meta http-equiv="X-UA-Compatible" content="IE=edge;"><style nonce="mqhuGPqBlRLcNbgNZAKoIA">@font-face{font-family:'Roboto';font-style:italic;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOkCnqEu92Fr1Mu51xIIzc.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:300;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmSU5fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:400;src:url(//fonts.gstatic.com/s/roboto/v18/KFOmCnqEu92Fr1Mu4mxP.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:500;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmEU9fBBc9.ttf)format('truetype');}@font-face{font-family:'Roboto';font-style:normal;font-weight:700;src:url(//fonts.gstatic.com/s/roboto/v18/KFOlCnqEu92Fr1MmWUlfBBc9.ttf)format('truetype');}</style><meta name="referrer" content="origin"><title>car_
# ...

# %% [markdown]
# ###### **Exercise 13:**
# join the cars dataframe with the car brands dataframe.

# %%
# your code here
#result = pd.concat([df1, df4], axis=1)

result = pd.concat([cars, CarBrands], axis = 1)

# %% [markdown]
# ###### **Bonus:**
# create 4 groups (bins) of cars, by Year. We want to explore how cars have evolved decade by decade.

# %%
# your code here
#
Eightys = cars[(cars.Year == 1984) | (cars.Year == 1985) | (cars.Year == 1986) | (cars.Year == 1987)| (cars.Year == 1988)]
Ninties = cars[(cars.Year == 1990) | (cars.Year == 1991)|(cars.Year == 1992) | (cars.Year == 1993)|(cars.Year == 1994) | (cars.Year == 1995)|(cars.Year == 1996) | (cars.Year == 1997)|(cars.Year == 1999)]
twothousands = cars[(cars.Year == 2000) | (cars.Year == 2001) | (cars.Year == 2002) | (cars.Year == 2003)| (cars.Year == 2004) |(cars.Year == 2005) | (cars.Year == 2006) | (cars.Year == 2007) | (cars.Year == 2008)| (cars.Year == 2009)]
twotens = cars[(cars.Year == 2010) | (cars.Year == 2011) | (cars.Year == 2012) | (cars.Year == 2013)| (cars.Year == 2014) |(cars.Year == 2015) | (cars.Year == 2016) | (cars.Year == 2017)]

print(Eightys)
print(Ninties)
print(twothousands)
print(twotens)

#cut_bins = [1980, 1990, 2000, 2010,2020]
#cars['decade'] = pd.cut(x = cars['Year'], bins=cut_bins)
#cars_decade = cars.groupby('decade')
#cars_decade["Fuel Cost/Year"].mean()


#gasEighties = cars.query('Year > 1980 & Year < 1989').mean()
#gasEighties.Fuel_Barrels_per_Year

#bins = [1980, 1990, 2000, 2010, 2020, 2030]
#total_cars['binned_Decade'] = pd.cut(total_cars['Year'], bins)
#print (total_cars)

#year_points = [1980, 1990, 2000, 2010,2020]
#cars['decade'] = pd.cut(x = cars['Year'], bins=year_points, labels=[u'80s', u'90s', u'00s', u'10s'])
#cars_decade = cars.groupby('decade')
#cars_decade.head()


#bins = [0, 1989, 1999, 2009, 2019]
#labels = ['80s', '90s', '00s', '10s']
#cars['bin_d'] = pd.cut(cars['Year'], bins = bins, labels = labels)
#cars
# Out:
#                    Make                Model  Year  EngineDisplacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                 2.5
# 1            AM General     FJ8c Post Office  1984                 4.2
# 2            AM General  Post Office DJ5 2WD  1985                 2.5
# 3            AM General  Post Office DJ8 2WD  1985                 4.2
# 4      ASC Incorporated                  GNX  1987                 3.8
# ...                 ...                  ...   ...                 ...
# 35318             Volvo                  780  1988                 2.8
# 35924              Yugo                   GV  1988                 1.1
# 35925              Yugo                   GV  1988                 1.3
# 35928              Yugo               GV/GVX  1987                 1.1
# 35931              Yugo          Gy/yugo GVX  1986                 1.1
#
#        Cylinders     Transmission         Drivetrain  \
# 0            4.0  Automatic 3-spd      2-Wheel Drive
# ...
